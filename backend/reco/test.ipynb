# %%
from CoalBlendPredictor import *

if __name__ == "__main__":
    # Initialize predictor
    predictor = CoalBlendPredictor()
    csv = predictor.predict_from_csv("D:\Recommendation\Blend_ratio_oct.csv", output_csv_path="D:\Recommendation\output1.csv", verbose=True)
    # # Single prediction
    # coal_blend = {
    #     'Goonyella': 50,
    #     'R.PCI': 50
    # }
    
    # result = predictor.predict(coal_blend, verbose=False)
    
    # if result['status'] == 'success':
    #     print(f"\n✅ Prediction successful!")
    #     print(f"CRI: {result['predictions']['CRI']:.2f}")
    #     print(f"CSR: {result['predictions']['CSR']:.2f}")
    #     print(f"ASH: {result['predictions']['ASH']:.2f}")
    #     print(f"VM: {result['predictions']['VM']:.2f}")
    # else:
    #     print(f"\n❌ Prediction failed: {result['error_message']}")
    
    # # Batch prediction example
    # print("\n" + "=" * 60)
    # print("BATCH PREDICTION EXAMPLE")
    # print("=" * 60)
    
    # blends = [
    #     {'Goonyella': 40, 'Peak Downs': 30, 'R.PCI': 30},
    #     {'Caval Ridge': 60, 'R.PCI': 40}
    # ]
    
    # batch_results = predictor.batch_predict(blends, verbose=False)
    
    # for i, result in enumerate(batch_results):
    #     if result['status'] == 'success':
    #         print(f"\nBlend {i+1}: CRI={result['predictions']['CRI']:.2f}, "
    #               f"CSR={result['predictions']['CSR']:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from CoalBlendPredictor import *
#       3 if __name__ == "__main__":
#       4     # Initialize predictor
#       5     predictor = CoalBlendPredictor()
#
# File d:\work\coal_blend\Recommendation\CoalBlendPredictor.py:6
#       4 import re
#       5 from pathlib import Path
# ----> 6 from pycaret.regression import load_model, predict_model
#       9 class CoalBlendPredictor:
#      10     """
#      11     Coal Blend Prediction System
#      12
#      13     Predicts CRI, CSR, ASH, and VM values based on coal blend ratios.
#      14     """
#
# ModuleNotFoundError: No module named 'pycaret'

# %% [markdown]
# Residual Inference code
