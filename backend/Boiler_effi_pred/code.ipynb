# %% [markdown]
# 1.Frontend User Input:
# Coal Ratios - user will select coal and percentage(check coal property data),
# 'Load',
# 'feed water temperature',
# 'Running plant load factor',
# 'Air to fuel ratio for mill'
#
# 2.Weighted average:
# Coal Ratios and coal property data(Coal Name, TM, IM, ASH, VM, FC, GCV, GCV (ARB))
#
# 3.Model Input:
# 'Load',
# 'feed water temperature',
# 'Running plant load factor',
# 'Air to fuel ratio for mill',
# 'TM_WA', 'IM_WA', 'ASH_WA',
# 'VM_WA', 'FC_WA',
# 'GCV_WA', 'GCV (ARB)_WA'
#
# 4.Model Output:
# 'Boiler Efficiency',
# 'Nox',
# 'UBC in BA',
# 'UBC in FA'
#
# 5.Frontend Output:
# 'Boiler Efficiency',
# 'Nox',
# 'UBC in BA',
# 'UBC in FA',
# 'GCV_WA',
# 'GCV (ARB)_WA'

# %%
import pandas as pd
import ast

# -----------------------------
# Load CSVs
# -----------------------------
coal_df = pd.read_csv("coal_property_data.csv")
blend_df = pd.read_csv("New_Blend_dict.csv")

# Clean column names
coal_df.columns = coal_df.columns.str.strip()
coal_df["Coal_Name"] = (
    coal_df["Coal_Name"]
    .astype(str)
    .str.strip()
)

# Set Coal_Name as index for fast lookup
coal_df.set_index("Coal_Name", inplace=True)

# -----------------------------
# Weighted average function
# -----------------------------
def calculate_weighted_average(blend_str):
    blend_dict = ast.literal_eval(blend_str)

    # Initialize weighted sums
    weighted_sum = {
        "TM": 0, "IM": 0, "ASH": 0, "VM": 0,
        "FC": 0, "GCV": 0, "GCV (ARB)": 0
    }

    for coal, pct in blend_dict.items():
        if coal not in coal_df.index:
            raise ValueError(f"Coal '{coal}' not found in coal properties CSV")

        for prop in weighted_sum.keys():
            weighted_sum[prop] += coal_df.loc[coal, prop] * pct

    # Divide by 100 to get weighted average
    weighted_avg = {k: v / 100 for k, v in weighted_sum.items()}

    return weighted_avg

# -----------------------------
# Apply to blend column
# -----------------------------
blend_df["Weighted_Average"] = blend_df["Blend"].apply(calculate_weighted_average)

print(blend_df["Weighted_Average"])
blend_df.to_csv("Final_weighted.csv")

# %%
import pandas as pd
import ast

# Read CSV
df = pd.read_csv("Final_weighted.csv")

# Convert string dict → actual dict
df["Weighted_Average"] = df["Weighted_Average"].apply(ast.literal_eval)

# Expand dictionary into columns
expanded_df = df["Weighted_Average"].apply(pd.Series)

# Save to CSV
expanded_df.to_csv("weighted_average.csv", index=False)

print(expanded_df)

# %%
pip install pycaret pandas scikit-learn

# %% [markdown]
# Model Training

# %%
import pandas as pd
from pycaret.regression import *

# ================================
# 1. Load Data
# ================================
df = pd.read_csv("Training_data.csv")
df.columns = df.columns.str.strip()
# ================================
# 2. Define Input & Target Columns
# ================================
input_features = [
    'Load',
    'feed water temperature',
    'Running plant load factor',
    'Air to fuel ratio for mill',
    'TM_WA', 'IM_WA', 'ASH_WA',
    'VM_WA', 'FC_WA',
    'GCV_WA', 'GCV (ARB)_WA'
]

target_variables = [
    'Boiler Efficiency',
    'Nox',
    'UBC in BA',
    'UBC in FA'
]

# ================================
# 3. Loop Over Each Target Variable
# ================================
for target in target_variables:
    
    print(f"\n==============================")
    print(f"Training model for: {target}")
    print(f"==============================\n")
    
    # Select relevant columns
    model_df = df[input_features + [target]].dropna()
    
    # ----------------------------
    # PyCaret Setup
    # ----------------------------
    setup(
        data=model_df,
        target=target,
        session_id=42,
        verbose=False
    )
    
    # ----------------------------
    # Compare Models
    # ----------------------------
    best_model = compare_models()
    
    # ----------------------------
    # Finalize Model
    # ----------------------------
    final_model = finalize_model(best_model)
    
    # ----------------------------
    # Save Model
    # ----------------------------
    model_name = target.replace(" ", "_").lower() + "_model"
    save_model(final_model, model_name)
    
    print(f"Model saved as: {model_name}.pkl")

print("\n✅ All models trained and saved successfully.")
# Out:
# ==============================
# Training model for: Boiler Efficiency
# ==============================
# <style type="text/css">
# #T_91d12 th {
#   text-align: left;
# }
# #T_91d12_row0_col0, #T_91d12_row0_col1, #T_91d12_row0_col3, #T_91d12_row0_col5, #T_91d12_row0_col6, #T_91d12_row1_col0, #T_91d12_row1_col1, #T_91d12_row1_col2, #T_91d12_row1_col3, #T_91d12_row1_col4, #T_91d12_row1_col5, #T_91d12_row1_col6, #T_91d12_row2_col0, #T_91d12_row2_col1, #T_91d12_row2_col2, #T_91d12_row2_col3, #T_91d12_row2_col4, #T_91d12_row2_col5, #T_91d12_row2_col6, #T_91d12_row3_col0, #T_91d12_row3_col2, #T_91d12_row3_col4, #T_91d12_row4_col0, #T_91d12_row4_col1, #T_91d12_row4_col2, #T_91d12_row4_col3, #T_91d12_row4_col4, #T_91d12_row4_col5, #T_91d12_row4_col6, #T_91d12_row5_col0, #T_91d12_row5_col1, #T_91d12_row5_col2, #T_91d12_row5_col3, #T_91d12_row5_col4, #T_91d12_row5_col5, #T_91d12_row5_col6, #T_91d12_row6_col0, #T_91d12_row6_col1, #T_91d12_row6_col2, #T_91d12_row6_col3, #T_91d12_row6_col4, #T_91d12_row6_col5, #T_91d12_row6_col6, #T_91d12_row7_col0, #T_91d12_row7_col1, #T_91d12_row7_col2, #T_91d12_row7_col3, #T_91d12_row7_col4, #T_91d12_row7_col5, #T_91d12_row7_col6, #T_91d12_row8_col0, #T_91d12_row8_col1, #T_91d12_row8_col2, #T_91d12_row8_col3, #T_91d12_row8_col4, #T_91d12_row8_col5, #T_91d12_row8_col6, #T_91d12_row9_col0, #T_91d12_row9_col1, #T_91d12_row9_col2, #T_91d12_row9_col3, #T_91d12_row9_col4, #T_91d12_row9_col5, #T_91d12_row9_col6, #T_91d12_row10_col0, #T_91d12_row10_col1, #T_91d12_row10_col2, #T_91d12_row10_col3, #T_91d12_row10_col4, #T_91d12_row10_col5, #T_91d12_row10_col6, #T_91d12_row11_col0, #T_91d12_row11_col1, #T_91d12_row11_col2, #T_91d12_row11_col3, #T_91d12_row11_col4, #
row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_91d12_row1_col1" class="data row1 col1" >0.0522</td>
#       <td id="T_91d12_row1_col2" class="data row1 col2" >0.0044</td>
#       <td id="T_91d12_row1_col3" class="data row1 col3" >0.0655</td>
#       <td id="T_91d12_row1_col4" class="data row1 col4" >0.9862</td>
#       <td id="T_91d12_row1_col5" class="data row1 col5" >0.0007</td>
#       <td id="T_91d12_row1_col6" class="data row1 col6" >0.0006</td>
#       <td id="T_91d12_row1_col7" class="data row1 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_91d12_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_91d12_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_91d12_row2_col1" class="data row2 col1" >0.0420</td>
#       <td id="T_91d12_row2_col2" class="data row2 col2" >0.0050</td>
#       <td id="T_91d12_row2_col3" class="data row2 col3" >0.0660</td>
#       <td id="T_91d12_row2_col4" class="data row2 col4" >0.9851</td>
#       <td id="T_91d12_row2_col5" class="data row2 col5" >0.0007</td>
#       <td id="T_91d12_row2_col6" class="data row2 col6" >0.0005</td>
#       <td id="T_91d12_row2_col7" class="data row2 col7" >0.4030</td>
#     </tr>
#     <tr>
#       <th id="T_91d12_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_91d12_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_91d12_row3_col1" class="data row3 col1" >0.0064</td>
#       <td id="T_91d12_row3_col2" class="data row3 col2" >0.0057</td>
#       <td id="T_91d12_row3_col3" class="data row3 col3" >0.0238</td>
#       <td id="T_91d12_row3_col4" class="data row3 col4" >0.9837</td>
#       <td id="T_91d12_row3_col5" class="data row3 col5" >0.0003</td>
#       <td id="T_91d12_row3_col6" class="data row3 col6" >0.0001</td>
#       <td id="T_91d12_row3_col7" class="data row3 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_91d12_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_91d12_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_91d12_row4_col1" class="data row4 col1" >0.0310</td>
#       <td id="T_91d12_row4_col2" class="data row4 col2" >0.0070</td>
#       <td id="T_91d12_row4_col3" class="data row4 col3" >0.0669</td>
#       <td id="T_91d12_row4_col4" class="data row4 col4" >0.9798</td>
#       <td id="T_91d12_row4_col5" class="data row4 col5" >0.0008</td>
#       <td id="T_91d12_row4_col6" class="data row4 col6" >0.0004</td>
#       <td id="T_91d12_row4_col7" class="data row4 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_91d12_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_91d12_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_91d12_row5_col1" class="data row5 col1" >0.0195</td>
#       <td id="T_91d12_row5_col2" class="data row5 col2" >0.0090</td>
#       <td id="T_91d12_row5_col3" class="data row5 col3" >0.054
# Transformation Pipeline and Model Successfully Saved
# Model saved as: boiler_efficiency_model.pkl
#
# ==============================
# Training model for: Nox
# ==============================
# <style type="text/css">
# #T_6d2c7 th {
#   text-align: left;
# }
# #T_6d2c7_row0_col0, #T_6d2c7_row1_col0, #T_6d2c7_row1_col1, #T_6d2c7_row1_col3, #T_6d2c7_row2_col0, #T_6d2c7_row2_col1, #T_6d2c7_row2_col2, #T_6d2c7_row2_col3, #T_6d2c7_row2_col5, #T_6d2c7_row2_col6, #T_6d2c7_row3_col0, #T_6d2c7_row3_col1, #T_6d2c7_row3_col3, #T_6d2c7_row4_col0, #T_6d2c7_row5_col0, #T_6d2c7_row5_col1, #T_6d2c7_row5_col2, #T_6d2c7_row5_col3, #T_6d2c7_row5_col4, #T_6d2c7_row5_col5, #T_6d2c7_row5_col6, #T_6d2c7_row6_col0, #T_6d2c7_row6_col1,
row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_27b72_row3_col1" class="data row3 col1" >1.0530</td>
#       <td id="T_27b72_row3_col2" class="data row3 col2" >2.3689</td>
#       <td id="T_27b72_row3_col3" class="data row3 col3" >1.5079</td>
#       <td id="T_27b72_row3_col4" class="data row3 col4" >0.6318</td>
#       <td id="T_27b72_row3_col5" class="data row3 col5" >0.1634</td>
#       <td id="T_27b72_row3_col6" class="data row3 col6" >0.1430</td>
#       <td id="T_27b72_row3_col7" class="data row3 col7" >0.3500</td>
#     </tr>
#     <tr>
#       <th id="T_27b72_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_27b72_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_27b72_row4_col1" class="data row4 col1" >1.1242</td>
#       <td id="T_27b72_row4_col2" class="data row4 col2" >2.3895</td>
#       <td id="T_27b72_row4_col3" class="data row4 col3" >1.5249</td>
#       <td id="T_27b72_row4_col4" class="data row4 col4" >0.6161</td>
#       <td id="T_27b72_row4_col5" class="data row4 col5" >0.1656</td>
#       <td id="T_27b72_row4_col6" class="data row4 col6" >0.1554</td>
#       <td id="T_27b72_row4_col7" class="data row4 col7" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_27b72_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_27b72_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_27b72_row5_col1" class="data row5 col1" >1.1026</td>
#       <td id="T_27b72_row5_col2" class="data row5 col2" >2.4785</td>
#       <td id="T_27b72_row5_col3" class="data row5 col3" >1.5687<
# Transformation Pipeline and Model Successfully Saved
# Model saved as: ubc_in_ba_model.pkl
#
# ==============================
# Training model for: UBC in FA
# ==============================
# <style type="text/css">
# #T_fd29a th {
#   text-align: left;
# }
# #T_fd29a_row0_col0, #T_fd29a_row1_col0, #T_fd29a_row1_col1, #T_fd29a_row1_col2, #T_fd29a_row1_col3, #T_fd29a_row1_col4, #T_fd29a_row1_col5, #T_fd29a_row1_col6, #T_fd29a_row2_col0, #T_fd29a_row2_col1, #T_fd29a_row2_col2, #T_fd29a_row2_col3, #T_fd29a_row2_col4, #T_fd29a_row2_col5, #T_fd29a_row2_col6, #T_fd29a_row3_col0, #T_fd29a_row3_col1, #T_fd29a_row3_col2, #T_fd29a_row3_col3, #T_fd29a_row3_col4, #T_fd29a_row3_col5, #T_fd29a_row3_col6, #T_fd29a_row4_col0, #T_fd29a_row4_col1, #T_fd29a_row4_col2, #T_fd29a_row4_col3, #T_fd29a_row4_col4, #T_fd29a_row4_col5, #T_fd29a_row4_col6, #T_fd29a_row5_col0, #T_fd29a_row5_col1, #T_fd29a_row5_col2, #T_fd29a_row5_col3, #T_fd29a_row5_col4, #T_fd29a_row5_col5, #T_fd29a_row5_col6, #T_fd29a_row6_col0, #T_fd29a_row6_col1, #T_fd29a_row6_col2, #T_fd29a_row6_col3, #T_fd29a_row6_col4, #T_fd29a_row6_col5, #T_fd29a_row6_col6, #T_fd29a_row7_col0, #T_fd29a_row7_col1, #T_fd29a_row7_col2, #T_fd29a_row7_col3, #T_fd29a_row7_col4, #T_fd29a_row7_col5, #T_fd29a_row7_col6, #T_fd29a_row8_col0, #T_fd29a_row8_col1, #T_fd29a_row8_col2, #T_fd29a_row8_col3, #T_fd29a_row8_col4, #T_fd29a_row8_col5, #T_fd29a_row8_col6, #T_fd29a_row9_col0, #T_fd29a_row9_col1, #T_fd29a_row9_col2, #T_fd29a_row9_col3, #T_fd29a_row9_col4, #T_fd29a_row9_col5, #T_fd29a_row9_col6, #T_fd29a_row10_col0, #T_fd29a_row10_col1, #T_fd29a_row10_col2, #T_fd29a_row10_col3, #T_fd29a_row10_col4, #T_fd29a_row10_col5, #T_fd29a_row10_col6, #T_fd29a_row11_col0, #T_fd29a_row11_col1, #T_fd29a_row11_col2, #T_fd29a_row11_col3, #T_fd29a_row11_col4, #T_fd29a_row11_col5, #T_fd29a_row11_col6, #T_fd29a_row12_col0, #T_fd29a_row12_col1, #T_fd29a_row12_col2, #T_fd29a_row12_col3, #T_fd29a_row12_col4, #T_fd29a_row12_col5, #T_fd29a_row12_col6, #T_fd29a_row13_col0, #T_fd29a_row13_col1, #T_fd29a_row13_col2, #T_fd29a_row13_col3, #T_fd29a_row13_col4, #T_fd29a_row13_col5, #T_fd29a_row13_col6, #T_fd29a_row14_col0, #T_fd29a_row14_col1, #T_fd29a_row14_col2, #T_fd29a_row14_col3, #T_fd29a_row14_col4, #T_fd29a_row14_col5, #T_fd29a_row14_col6, #T_fd29a_row15_col0, #T_fd29a_row15_col1, #T_fd29a_row15_col2, #T_fd29a_row15_col3, #T_fd29a_row15_col4, #T_fd29a_row15_col5, #T_fd29a_row15_col6, #T_fd29a_row16_col0, #T_fd29a_row16_col1, #T_fd29a_row16_col2, #T_fd29a_row16_col3, #T_fd29a_row16_col4, #T_fd29a_row16_col5, #T_fd29a_row16_col6, #T_fd29a_row17_col0, #T_fd29a_row17_col1, #T_fd29a_row17_col2, #T_fd29a_row17_col3, #T_fd29a_row17_col4, #T_fd29a_row17_col5, #T_fd29a_row17_col6, #T_fd29a_row18_col0, #T_fd29a_row18_col1, #T_fd29a_row18_col2, #T_fd29a_row18_col3, #T_fd29a_row18_col4, #T_fd29a_row18_col5, #T_fd29a_row18_col6, #T_fd29a_row19_col0, #T_fd29a_row19_col1, #T_fd29a_row19_col2, #T_fd29a_row19_col3, #T_fd29a_row19_col4, #T_fd29a_row19_col5, #T_fd29a_row19_col6 {
#   text-align: left;
# }
# #T_fd29a_row0_col1, #T_fd29a_row0_col2, #T_fd29a_row0_col3, #T_fd29a_row0_col4, #T_fd29a_row0_col5, #T_fd29a_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fd29a_row0_col7, #T_fd29a_row1_col7, #T_fd29a_row2_col7, #T_fd29a_row3_col7, #T_fd29a_row4_col7, #T_fd29a_row5_col7, #T_fd29a_row6_col7, #T_fd29a_row7_col7, #T_fd29a_row8_col7, #T_fd29a_row9_col7, #T_fd29a_row10_col7, #T_fd29a_row11_col7, #T_fd29a_row12_col7, #T_fd29a_row13_col7, #T_fd29a_row15_col7, #T_fd29a_row16_col7, #T_fd29a_row17_col7, #T_fd29a_row18_col7, #T_fd29a_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fd29a_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fd29a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd29a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fd29a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fd29a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fd29a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fd29a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fd29a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fd29a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fd29a_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd29a_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_fd29a_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_fd29a_row0_col1" class="data row0 col1" >0.9103</td>
#       <td id="T_fd29a_row0_col2" class="data row0 col2" >1.7272</td>
#       <td id="T_fd29a_row0_col3" class="data row0 col3" >1.2989</td>
#       <td id="T_fd29a_row0_col4" class="data row0 col4" >0.7026</td>
#       <td id="T_fd29a_row0_col5" class="data row0 col5" >0.1698</td>
#       <td id="T_fd29a_row0_col6" class="data row0 col6" >0.1631</td>
#       <td id="T_fd29a_row0_col7" class="data row0 col7" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_fd29a_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_fd29a_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_fd29a_row1_col1" class="data row1 col1" >0.9536</td>
#       <td id="T_fd29a_row1_col2" class="data row1 col2" >1.8350</td>
#       <td id="T_fd29a_row1_col3" class="data row1 col3" >1.3329</td>
#       <td id="T_fd29a_row1_col4" class="data row1 col4" >0.7004</td>
#       <td id="T_fd29a_row1_col5" class="data row1 col5" >0.1734</td>
#       <td id="T_fd29a_row1_col6" class="data row1 col6" >0.1670</td>
#       <td id="T_fd29a_row1_col7" class="data row1 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_fd29a_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_fd29a_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_fd29a_row2_col1" class="data row2 col1" >0.9687</td>
#       <td id="T_fd29a_row2_col2" class="data row2 col2" >1.9006</td>
#       <td id="T_fd29a_row2_col3" class="data row2 col3" >1.3488</td>
#       <td id="T_fd29a_row2_col4" class="data row2 col4" >0.6783</td>
#       <td id="T_fd29a_row2_col5" class="data row2 col5" >0.1839</td>
#       <td id="T_fd29a_row2_col6" class="data row2 col6" >0.1750</td>
#       <td id="T_fd29a_row2_col7" class="data row2 col7" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_fd29a_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_fd29a_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_fd29a_row3_col1" class="data row3 col1" >0.9948</td>
#       <td id="T_fd29a_row3_col2" class="data row3 col2" >1.9311</td>
#       <td id="T_fd29a_row3_col3" class="data row3 col3" >1.3688</td>
#       <td id="T_fd29a_row3_col4" class="data row3 col4" >0.6594</td>
#       <td id="T_fd29a_row3_col5" class="data row3 col5" >0.1854</td>
#       <td id="T_fd29a_row3_col6" class="data row3 col6" >0.1813</td>
#       <td id="T_fd29a_row3_col7" class="data row3 col7" >0.3590</td>
#     </tr>
#     <tr>
#       <th id="T_fd29a_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_fd29a_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_fd29a_row4_col1" class="data row4 col1" >0.9514</td>
#       <td id="T_fd29a_row4_col2" class="data row4 col2" >1.8707</td>
#       <td id="T_fd29a_row4_col3" class="data row4 col3" >1.3448</td>
#       <td id="T_fd29a_row4_col4" class="data row4 col4" >0.6409</td>
#       <td id="T_fd29a_row4_col5" class="data row4 col5" >0.1720</td>
#       <td id="T_fd29a_row4_col6" class="data row4 col6" >0.1667</td>
#       <td id="T_fd29a_row4_col7" class="data row4 col7" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_fd29a_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_fd29a_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_fd29a_row5_col1" class="data row5 col1" >1.0605</td>
#       <td id="T_fd29a_row5_col2" class="data row5 col2" >2.0512</td>
#       <td id="T_fd29a_row5_col3" class="data row5 col3" >1.4190<
# Transformation Pipeline and Model Successfully Saved
# Model saved as: ubc_in_fa_model.pkl
#
# ✅ All models trained and saved successfully.
